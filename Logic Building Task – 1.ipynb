# %%
#Question 1: To identify valid credentials
# Predefined credentials
correct_username = "admin"
correct_password = "1234"

# Accept input from user
username = input("Enter Username: ")
password = input("Enter Password: ")

# Check login credentials
if username == correct_username and password == correct_password:
    print("Login Successful")
else:
    print("Invalid Credentials")
# Out:
# Enter Username:  admin
# Enter Password:  1234
# Login Successful

# %%
# Question 2:  Pass/Fail Analyzer
marks=[45, 78, 90, 33, 60]

# Initialize counters
pass_count = 0
fail_count = 0

# Analyze results
for m in marks:
    if m >= 50:
        pass_count += 1
    else:
        fail_count += 1

# Print final output
print("Total Students:", len(marks))
print("Pass Students:", pass_count)
print("Fail Students:", fail_count)
# Out:
# Total Students: 5
# Pass Students: 3
# Fail Students: 2

# %%
# Question 3: Simple Data Cleaner
names = [" Alice ", "bob", " CHARLIE "]

correct_names = []

for name in names:
    cleaned_name = name.strip().lower()
    correct_names.append(cleaned_name)

# Print Correct List
print("Correct Names:", correct_names)
# Out:
# Correct Names: ['alice', 'bob', 'charlie']

# %%
# Question 4: Message Length Analyzer

messages = ["Hi", "Welcome to the platform", "OK"]
# Analyze each message
for msg in messages:
    length = len(msg)
    print("Message:", msg)
    print("Length:", length)
    
    if length > 10:
        print("Status: Long Message")
    else:
        print("Status: Short Message")
# Out:
# Message: Hi
# Length: 2
# Status: Short Message
# Message: Welcome to the platform
# Length: 23
# Status: Long Message
# Message: OK
# Length: 2
# Status: Short Message

# %%
#Question 5: Error Message Detector
logs = ["INFO", "ERROR", "WARNING", "ERROR"]

# Count ERROR entries
error_count = logs.count("ERROR")
#Result
print("Total ERROR entries:", error_count)
# Out:
# Total ERROR entries: 2
